# %%
# webscraping
import os, json  # json for pretty output
from serpapi import GoogleSearch
import requests

def get_google_images():
    params = {
        # "api_key": os.environ.get("SERPAPI_KEY"),
        "api_key": "c6d0a231043ade221eb18c36fb28d2cf9f48760afc5609669181aa34b5032052",
        "engine": "google",
        "q": "Cat", # query 
        "tbm": "isch", # images
        "ijn": 0 # page number
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    print(results)

    # print(json.dumps(results['suggested_searches'], indent=2, ensure_ascii=False))
    print(json.dumps(results["images_results"], indent=2, ensure_ascii=False))
    # save files to /SerpApi_Images/ if it doesn't exist create the folder
    if not os.path.exists("./SerpApi_Images/"):
        os.makedirs("./SerpApi_Images/")

    # -----------------------
    # Downloading images
    headers = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36"}

    for index, image in enumerate(results["images_results"]):

        try:
            print(f"Downloading {index} image...")

            # filepath is current working directory + SerpApi_Images + params["q"] + index + .jpg
            filepath = os.path.join("./SerpApi_Images/", params["q"] + str(index) + ".jpg")

            response = requests.get(image['original'], headers=headers).content
            with open(filepath, "wb") as f:
                f.write(response)

        except Exception as e:
            print(e)
            print(f"Error downloading {index} image. Error =", e)

get_google_images()
# Out:
# https://serpapi.com/search
# {'search_metadata': {'id': '62d98a318ccee0212c7b6eed', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/12565aa211a45b7e/62d98a318ccee0212c7b6eed.json', 'created_at': '2022-07-21 17:17:37 UTC', 'processed_at': '2022-07-21 17:17:37 UTC', 'google_url': 'https://www.google.com/search?q=Cat&oq=Cat&tbm=isch&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/12565aa211a45b7e/62d98a318ccee0212c7b6eed.html', 'total_time_taken': 0.81}, 'search_parameters': {'engine': 'google', 'q': 'Cat', 'google_domain': 'google.com', 'ijn': '0', 'device': 'desktop', 'tbm': 'isch'}, 'search_information': {'image_results_state': 'Results for exact spelling', 'query_displayed': 'Cat'}, 'suggested_searches': [{'name': 'wallpaper', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:wallpaper:9CZeCAsFLvU%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoAHoECAEQIA', 'chips': 'q:cat,g_1:wallpaper:9CZeCAsFLvU%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Awallpaper%3A9CZeCAsFLvU%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f441d9053c326eeaf1680eba43d37af0e7e.jpeg'}, {'name': 'kitten', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:kitten:mKwlpf6SlcM%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoAXoECAEQIg', 'chips': 'q:cat,g_1:kitten:mKwlpf6SlcM%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Akitten%3AmKwlpf6SlcM%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f4413e662d61f8b747b44a4286744efefd5.jpeg'}, {'name': 'anime', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:anime:6J_67Cx_pgI%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoAnoECAEQJA', 'chips': 'q:cat,g_1:anime:6J_67Cx_pgI%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Aanime%3A6J_67Cx_pgI%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f44eba5d33dc63441ab72f83d236a172071.jpeg'}, {'name': 'drawing', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:drawing:zi_1P2U4tLk%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoA3oECAEQJg', 'chips': 'q:cat,g_1:drawing:zi_1P2U4tLk%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Adrawing%3Azi_1P2U4tLk%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f4419004d8f1d1e0b5965a06f39bbe5a371.jpeg'}, {'name': 'baby', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:baby:8mDLbch67fs%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoBHoECAEQKA', 'chips': 'q:cat,g_1:baby:8mDLbch67fs%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Ababy%3A8mDLbch67fs%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f444635bdbe02303adc31db180e4d48d777.jpeg'}, {'name': 'kawaii', 'link': 'https://www.google.com/search?q=Cat&tbm=isch&chips=q:cat,g_1:kawaii:sxQ1M_w906o%3D&hl=en-US&sa=X&ved=2ahUKEwj38sGnvor5AhXUn3IEHZYBAIcQ4lYoBXoECAEQKg', 'chips': 'q:cat,g_1:kawaii:sxQ1M_w906o%3D', 'serpapi_link': 'https://serpapi.com/search.json?chips=q%3Acat%2Cg_1%3Akawaii%3AsxQ1M_w906o%253D&device=desktop&engine=google&google_domain=google.com&ijn=0&q=Cat&tbm=isch', 'thumbnail': 'https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/0f3acdf18c9a65beeccf8d22b5c86f4462057257614124e3483585fc0262536b.j ...
# [
#   {
#     "position": 1,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa8598b11b4a554c92cb1679c7a64b02906137b9bd439add7cc.jpeg",
#     "source": "en.wiktionary.org",
#     "title": "cat - Wiktionary",
#     "link": "https://en.wiktionary.org/wiki/cat",
#     "original": "https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/1200px-Cat03.jpg",
#     "is_product": false
#   },
#   {
#     "position": 2,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e65f0ec3b75dae1a590f37f5f4ce35ffcf.jpeg",
#     "source": "nationalgeographic.com",
#     "title": "Cat | National Geographic",
#     "link": "https://www.nationalgeographic.com/animals/mammals/facts/domestic-cat",
#     "original": "https://i.natgeofe.com/n/46b07b5e-1264-42e1-ae4b-8a021226e2d0/domestic-cat_thumb_square.jpg",
#     "is_product": false
#   },
#   {
#     "position": 3,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa89e2abd13c3a733b8b390872902d9d0881e8b453781853426.jpeg",
#     "source": "en.wikipedia.org",
#     "title": "Cat - Wikipedia",
#     "link": "https://en.wikipedia.org/wiki/Cat",
#     "original": "https://upload.wikimedia.org/wikipedia/commons/0/0b/Cat_poster_1.jpg",
#     "is_product": false
#   },
#   {
#     "position": 4,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84dd554c9007be7a376de16c17cfff7873972c1755f844bff.jpeg",
#     "source": "icatcare.org",
#     "title": "Thinking of getting a cat? | International Cat Care",
#     "link": "https://icatcare.org/advice/thinking-of-getting-a-cat/",
#     "original": "https://icatcare.org/app/uploads/2018/07/Thinking-of-getting-a-cat.png",
#     "is_product": false
#   },
#   {
#     "position": 5,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa833dff8be902e38e1f7632060dbe459542d295227fec81967.jpeg",
#     "source": "en.wikipedia.org",
#     "title": "Cat training - Wikipedia",
#     "link": "https://en.wikipedia.org/wiki/Cat_training",
#     "original": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/1200px-Cat_November_2010-1a.jpg",
#     "is_product": false
#   },
#   {
#     "position": 6,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa80f6cc93bc96aa975535590e864fda70b3ff99bb8a63022c0.jpeg",
#     "source": "britannica.com",
#     "title": "cat | Breeds & Facts | Britannica",
#     "link": "https://www.britannica.com/animal/cat",
#     "original": "https://cdn.britannica.com/39/7139-050-A88818BB/Himalayan-chocolate-point.jpg",
#     "is_product": false
#   },
#   {
#     "position": 7,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84ee3d7786e73c209b8622e7ed04a7eec6c13c318e2f1d715.jpeg",
#     "source": "npr.org",
#     "title": "Are Cats Really Aloof? : Short Wave : NPR",
#     "link": "https://www.npr.org/2021/08/10/1026508261/does-your-cat-like-you-or-just-tolerate-you",
#     "original": "https://media.npr.org/assets/img/2021/08/11/gettyimages-1279899488_wide-f3860ceb0ef19643c335cb34df3fa1de166e2761-s1100-c50.jpg",
#     "is_product": false
#   },
#   {
#     "position": 8,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa8d2a7852e1ab5bdcc16bb138e823ad9112b0d5a0c0a0eef63.jpeg",
#     "source": "humanesociety.org",
#     "title": "The cat's meow | The Humane Society of the United States",
#     "link": "https://www.humanesociety.org/resources/cats-meow",
#     "original": "https://www.humanesociety.org/sites/default/files/styles/1240x698/public/2020-07/kitten-510651.jpg?h=f54c7448&itok=ZhplzyJ9",
#     "is_product": false
#   },
#   {
#     "position": 9,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa83c5366dcdfd89c779f1cdc67ecd3b710e39bb7b7e340dce6.jpeg",
#     "source": "britannica.com",
#     "title": "cat | Breeds & Facts | Britannica",
#     "link": "https://www.britannica.com/animal/cat",
#     "original": "https://cdn.britannica.com/25/7125-050-67ACEC3C/Abyssinian-sorrel.jpg",
#     "is_product": false
#   },
#   {
#     "position": 10,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa8382a54067789434890b12217d312475cbfd0c0b4e6dcb421.jpeg",
#     "source": "rd.com",
#     "title": "22 Beautiful Black Cat Breeds | Reader's Digest",
#     "link": "https://www.rd.com/list/black-cat-breeds/",
#     "original": "https://www.rd.com/wp-content/uploads/2021/01/GettyImages-1175550351.jpg",
#     "is_product": false
#   },
#   {
#     "position": 11,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e6c0547dd680a7e73a7d9224a82f7add5f.jpeg",
#     "source": "pets.webmd.com",
#     "title": "Is My Cat Normal?",
#     "link": "https://pets.webmd.com/cats/ss/slideshow-is-my-cat-normal",
#     "original": "https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/slideshows/is_my_cat_normal_slideshow/1800x1200_is_my_cat_normal_slideshow.jpg",
#     "is_product": false
#   },
#   {
#     "position": 12,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e60fa52a869052fafaaa466e7dc031a999.jpeg",
#     "source": "icatcare.org",
#     "title": "International Cat Care | For the love of cats",
#     "link": "https://icatcare.org/",
#     "original": "https://icatcare.org/app/uploads/2018/06/Layer-1704-1200x630.jpg",
#     "is_product": false
#   },
#   {
#     "position": 13,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e6d859bd1aa96fc558a356456a8098e8ec.jpeg",
#     "source": "thesprucepets.com",
#     "title": "What Your Cat Is Saying With Its Eyes",
#     "link": "https://www.thesprucepets.com/cat-talk-eyes-553942",
#     "original": "https://www.thesprucepets.com/thmb/QDw4vt7XXQejL2IRztKeRLow6hA=/2776x1561/smart/filters:no_upscale()/cat-talk-eyes-553942-hero-df606397b6ff47b19f3ab98589c3e2ce.jpg",
#     "is_product": false
#   },
#   {
#     "position": 14,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e693cad99c0c1796c4ca4c5e70755b7aed.jpeg",
#     "source": "unsplash.com",
#     "title": "500+ Beautiful Cat Pictures [HD] | Download Free Images on Unsplash",
#     "link": "https://unsplash.com/s/photos/beautiful-cat",
#     "original": "https://images.unsplash.com/photo-1615789591457-74a63395c990?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8MXx8YmVhdXRpZnVsJTIwY2F0fGVufDB8fDB8fA%3D%3D&w=1000&q=80",
#     "is_product": false
#   },
#   {
#     "position": 15,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e60032ddec7ba7b49978f3156868098da9.jpeg",
#     "source": "wired.co.uk",
#     "title": "Is my cat happy? This app predicts feline moods | WIRED UK",
#     "link": "https://www.wired.co.uk/article/tably-cat-happy-facial-expression",
#     "original": "https://media.wired.co.uk/photos/60c8730fa81eb7f50b44037e/3:2/w_3329,h_2219,c_limit/1521-WIRED-Cat.jpeg",
#     "is_product": false
#   },
#   {
#     "position": 16,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e686d7c702c1c381fd178be17736e3b760.jpeg",
#     "source": "dkfindout.com",
#     "title": "Cat Facts for Kids | What is a Cat | DK Find Out",
#     "link": "https://www.dkfindout.com/us/animals-and-nature/cats/what-is-cat/",
#     "original": "https://res.cloudinary.com/dk-find-out/image/upload/q_70,c_pad,w_1200,h_630,f_auto/DCTM_Penguin_UK_DK_AL697473_RGB_PNG_namnse.jpg",
#     "is_product": false
#   },
#   {
#     "position": 17,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e6ff845b5bbf70f9f5254e63bbc90fe1db.jpeg",
#     "source": "nytimes.com",
#     "title": "Study Shows Case of Likely Cat-to-Human Virus Spread, but Risk Remains Low  - The New York Times",
#     "link": "https://www.nytimes.com/2022/06/10/health/cat-human-covid-transmission.html",
#     "original": "https://static01.nyt.com/images/2022/06/10/science/10virus-briefing-cat-transmission-b/10virus-briefing-cat-transmission-videoSixteenByNine3000.jpg",
#     "is_product": false
#   },
#   {
#     "position": 18,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e69367df73bd8502f150bdd24f69113b87.jpeg",
#     "source": "britannica.com",
#     "title": "The 10 Best Types of Cat | Britannica",
#     "link": "https://www.britannica.com/list/the-10-best-types-of-cat",
#     "original": "https://cdn.britannica.com/91/181391-050-1DA18304/cat-toes-paw-number-paws-tiger-tabby.jpg?q=60",
#     "is_product": false
#   },
#   {
#     "position": 19,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e648f31e10eb6d75964484d7a0b6504959.jpeg",
#     "source": "businessinsider.com",
#     "title": "German Cat Owners Ordered to Keep Cats Inside to Protect a Rare Bird",
#     "link": "https://www.businessinsider.com/german-cat-owners-ordered-keep-cats-inside-protect-rare-bird-2022-5",
#     "original": "https://i.insider.com/61d1c0e2aa741500193b2d18?width=700",
#     "is_product": false
#   },
#   {
#     "position": 20,
#     "thumbnail": "https://serpapi.com/searches/62d98a318ccee0212c7b6eed/images/446ea880ae628fa84f05dc3a53f104e6aa43eaa705ae360e6dff0dabd38a4a0f.jpeg",
#     "source": "scientificamerican.com",
#     "title": "Sequencing Cat Genomes Could Help Breed Healthier Kitties - Scientific  American",
#     "link": "https://www.scientificamerican.com/article/sequencing-cat-genomes-could-help-breed-healthier-kitties/",
#     "original": "https://static.scientificamerican.com/sciam/cache/file/1E3A3E62-B3CA-434A-8C3B3ED0C982FB69_source.jpg",
#     "is_product": false
#   },
#   {
#     "position": 21,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJ0MSxjFuwQmfxBRzegg2UKIo5QDASZqvNbA&usqp=CAU",
#     "source": "helpguide.org",
#     "title": "The Joys of Owning a Cat - HelpGuide.org",
#     "link": "https://www.helpguide.org/articles/healthy-living/joys-of-owning-a-cat.htm",
#     "original": "https://www.helpguide.org/wp-content/uploads/man-in-bed-cradling-cat.jpg",
#     "is_product": false
#   },
#   {
#     "position": 22,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQeWkXy00ZIFJ2MgcpmoobR-MMkMzBNxx-_8Q&usqp=CAU",
#     "source": "youtube.com",
#     "title": "Baby Cats - Cute and Funny Cat Videos Compilation #34 | Aww Animals -  YouTube",
#     "link": "https://www.youtube.com/watch?v=ByH9LuSILxU",
#     "original": "https://i.ytimg.com/vi/ByH9LuSILxU/maxresdefault.jpg",
#     "is_product": true
#   },
#   {
#     "position": 23,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLliy_lUMzOFFvxRihBMwas458el-v3g6U5Q&usqp=CAU",
#     "source": "nationalgeographic.com",
#     "title": "Why You're Probably Training Your Cat All Wrong",
#     "link": "https://www.nationalgeographic.com/animals/article/animals-cats-training-pets",
#     "original": "https://i.natgeofe.com/n/3861de2a-04e6-45fd-aec8-02e7809f9d4e/02-cat-training-NationalGeographic_1484324_3x4.jpg",
#     "is_product": false
#   },
#   {
#     "position": 24,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSy2UfltbvWh1nQog46XrjX8jGZlGdzb5dXYg&usqp=CAU",
#     "source": "dailysabah.com",
#     "title": "World's most popular cat breeds | Daily Sabah",
#     "link": "https://www.dailysabah.com/gallery/worlds-most-popular-cat-breeds/images",
#     "original": "https://idsb.tmgrup.com.tr/ly/uploads/images/2021/09/08/thumbs/800x531/142774.jpg",
#     "is_product": false
#   },
#   {
#     "position": 25,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTpyl4OX0AVWFBNDTR8Wat6VkawL6FG-ZPbmw&usqp=CAU",
#     "source": "scientificamerican.com",
#     "title": "Why do cats purr? - Scientific American",
#     "link": "https://www.scientificamerican.com/article/why-do-cats-purr/",
#     "original": "https://static.scientificamerican.com/sciam/cache/file/9CAE9C60-8BC5-4CA3-95C180EFACDD99FD.jpg",
#     "is_product": false
#   },
#   {
#     "position": 26,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLSWXMnKZ2greqzWZnlnqa7_Yw3SBYRgvDqw&usqp=CAU",
#     "source": "theverge.com",
#     "title": "Soon, the internet will make its own cat photos and then it won't need us -  The Verge",
#     "link": "https://www.theverge.com/2021/4/12/22379880/artificial-intelligence-cat-photos-gan",
#     "original": "https://cdn.vox-cdn.com/thumbor/0xNZ3CHLUku2UNu7ShU7bVFmr3k=/1400x1400/filters:format(jpeg)/cdn.vox-cdn.com/uploads/chorus_asset/file/22438301/fake_cats.jpg",
#     "is_product": false
#   },
#   {
#     "position": 27,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRyz1ijeacvTZ9OobxIrzqCcHIZJKF9wKCZJQ&usqp=CAU",
#     "source": "theconversation.com",
#     "title": "How we found coronavirus in a cat",
#     "link": "https://theconversation.com/how-we-found-coronavirus-in-a-cat-143697",
#     "original": "https://images.theconversation.com/files/350865/original/file-20200803-24-50u91u.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1200&h=1200.0&fit=crop",
#     "is_product": false
#   },
#   {
#     "position": 28,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRsUMjPWJM2TXEK6Djy50MhsT42SopKYfWU-Q&usqp=CAU",
#     "source": "nationaltoday.com",
#     "title": "International Cat Day",
#     "link": "https://nationaltoday.com/international-cat-day/",
#     "original": "https://nationaltoday.com/wp-content/uploads/2020/08/international-cat-day.jpg",
#     "is_product": false
#   },
#   {
#     "position": 29,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRjbPdsMTCNZcwI9y_ebV7jyf3ImNDqNYUOdg&usqp=CAU",
#     "source": "thesprucepets.com",
#     "title": "How to Determine Your Cat's Age",
#     "link": "https://www.thesprucepets.com/how-is-a-cats-age-determined-554296",
#     "original": "https://www.thesprucepets.com/thmb/FfEAaq_eXMxruRAZWVxooL2cWgU=/4749x4749/smart/filters:no_upscale()/how-is-a-cats-age-determined-554296-01-52252e4c987b4655a4bf14394757e54e.jpg",
#     "is_product": false
#   },
#   {
#     "position": 30,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRubLv76mdfM274kbRU8XKTMyWmSbdm9e9Ibg&usqp=CAU",
#     "source": "vox.com",
#     "title": "A cat who doesn't like me is the best £85 I ever spent” - Vox",
#     "link": "https://www.vox.com/22440221/best-money-quarantine-cat-pet",
#     "original": "https://cdn.vox-cdn.com/thumbor/KebUREZeTMw3U3RU5qAAd1BSbAs=/1400x1400/filters:format(jpeg)/cdn.vox-cdn.com/uploads/chorus_asset/file/22520158/Cat.jpg",
#     "is_product": false
#   },
#   {
#     "position": 31,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQWSOfVKWeUXO1igbOj5_JZ0ZehxDhk0DL2xw&usqp=CAU",
#     "source": "cosmopolitan.com",
#     "title": "50 Best Cat Names - Popular Names for Your Pet Cat",
#     "link": "https://www.cosmopolitan.com/lifestyle/a29538844/popular-cat-names/",
#     "original": "https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/close-up-of-cat-wearing-sunglasses-while-sitting-royalty-free-image-1571755145.jpg",
#     "is_product": false
#   },
#   {
#     "position": 32,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcToJey2FR2kEDYmQSQZFMwo0ia0s34xMvFxZA&usqp=CAU",
#     "source": "pets.webmd.com",
#     "title": "The Shots Your Cat Needs",
#     "link": "https://pets.webmd.com/cats/cat-vaccines",
#     "original": "https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/other/cat_relaxing_on_patio_other/1800x1200_cat_relaxing_on_patio_other.jpg",
#     "is_product": false
#   },
#   {
#     "position": 33,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpowklXrWS-c8UwSbX2HikrN3DqLmsf8IBPA&usqp=CAU",
#     "source": "purina.co.uk",
#     "title": "The Cat Health Checklist: Everything You Need to Know | Purina",
#     "link": "https://www.purina.co.uk/articles/cats/health/daily-care/general-cat-health-tips",
#     "original": "https://www.purina.co.uk/sites/default/files/2021-01/Article%20Hero-%20cat%20health.jpg",
#     "is_product": false
#   },
#   {
#     "position": 34,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlNyI5Bbsl1vq1BQjH9XA-Z4j0Kkk0cEpAnA&usqp=CAU",
#     "source": "en.wikipedia.org",
#     "title": "Van cat - Wikipedia",
#     "link": "https://en.wikipedia.org/wiki/Van_cat",
#     "original": "https://upload.wikimedia.org/wikipedia/commons/b/b1/VAN_CAT.png",
#     "is_product": false
#   },
#   {
#     "position": 35,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFLQMEGR7ATeqhlmDIdUxgW7ifxVzScZ8ghw&usqp=CAU",
#     "source": "theverge.com",
#     "title": "Soon, the internet will make its own cat photos and then it won't need us -  The Verge",
#     "link": "https://www.theverge.com/2021/4/12/22379880/artificial-intelligence-cat-photos-gan",
#     "original": "https://cdn.vox-cdn.com/thumbor/5hjeoXGrD-9dsTQC36Eh0ZeHQoE=/0x0:984x982/1200x0/filters:focal(0x0:984x982):no_upscale()/cdn.vox-cdn.com/uploads/chorus_asset/file/22438212/Screen_Shot_2021_04_12_at_8.15.22_AM.png",
#     "is_product": false
#   },
#   {
#     "position": 36,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjK41ynOnDcamZS7dUj-UioITQ2wnDOxtFFw&usqp=CAU",
#     "source": "theguardian.com",
#     "title": "What does your cat mean by 'miaow'? Let Japan's pet guru Yuki Hattori  explain | Cats | The Guardian",
#     "link": "https://www.theguardian.com/lifeandstyle/2020/sep/05/what-cats-mean-by-miaow-japans-pet-guru-knows-just-what-your-feline-friend-wants",
#     "original": "https://i.guim.co.uk/img/media/26392d05302e02f7bf4eb143bb84c8097d09144b/446_167_3683_2210/master/3683.jpg?width=1200&height=900&quality=85&auto=format&fit=crop&s=11e949fc5d06576bc8b80ec192896753",
#     "is_product": false
#   },
#   {
#     "position": 37,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSB78-SmhT6QFR2fupKiDNw1uyOXNvJRWA6gg&usqp=CAU",
#     "source": "courierpress.com",
#     "title": "Cat overpopulation too much for VHS Evansville, other groups",
#     "link": "https://www.courierpress.com/story/news/local/2022/06/15/evansville-cat-overpopulation-vanderburgh-humane-society-animal-control-care-warrick/9794693002/",
#     "original": "https://www.gannett-cdn.com/presto/2022/06/12/PEVC/a034649e-5e2e-4dc3-933f-44d3fb6a9386-2_CATS_1A.JPG?crop=4499,2531,x1,y0&width=3200&height=1801&format=pjpg&auto=webp",
#     "is_product": false
#   },
#   {
#     "position": 38,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJX2J1v_Wz7UlxE2BqaJM17PpoY2bGcMNLvQ&usqp=CAU",
#     "source": "theatlantic.com",
#     "title": "Cat Genomes Look a Lot Like Ours - The Atlantic",
#     "link": "https://www.theatlantic.com/science/archive/2021/07/cat-genomes/619587/",
#     "original": "https://cdn.theatlantic.com/thumbor/44PpR3XR0dpg8VHqNIIk87JGmmY=/0x0:4897x2755/960x540/media/img/mt/2021/07/GettyImages_473437806_copy/original.jpg",
#     "is_product": false
#   },
#   {
#     "position": 39,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSilQtmgona6EuTe9ISQteBQ9NKLHoOlFgHVA&usqp=CAU",
#     "source": "petco.com",
#     "title": "Cat & Kitten Supplies, Accessories & Products | Petco",
#     "link": "https://www.petco.com/shop/en/petcostore/category/cat",
#     "original": "https://assets.petco.com/petco/image/upload/f_auto,q_auto/category-cat-food-img-092220-330w-330h",
#     "is_product": false
#   },
#   {
#     "position": 40,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLbCtFQVD_8JgHh7Ayo6G1m-xJ63ttUWhYZg&usqp=CAU",
#     "source": "latimes.com",
#     "title": "Editorial: It's time to scratch gruesome cat declawing surgery in  California - Los Angeles Times",
#     "link": "https://www.latimes.com/opinion/story/2022-06-17/time-to-scratch-the-gruesome-declawing-procedure-for-cats-in-california",
#     "original": "https://ca-times.brightspotcdn.com/dims4/default/dfe8fc7/2147483647/strip/true/crop/1500x1341+0+0/resize/840x751!/quality/90/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F03%2Fd0%2F27b739f74940a48564e165c17e66%2Fla-ed-scratch-cat-declawing.jpg",
#     "is_product": false
#   },
#   {
#     "position": 41,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-Z7Sd5LYKwG_2erz4NPxaEn1D3jbcZKgjTQ&usqp=CAU",
#     "source": "theconversation.com",
#     "title": "The curious character of cats – and whether they are really more aloof",
#     "link": "https://theconversation.com/the-curious-character-of-cats-and-whether-they-are-really-more-aloof-75512",
#     "original": "https://images.theconversation.com/files/168121/original/file-20170505-1693-ymh4bc.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1200&h=900.0&fit=crop",
#     "is_product": false
#   },
#   {
#     "position": 42,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS2CDqznabfgQu6UCM7iCVesi3qeoH8hviKgQ&usqp=CAU",
#     "source": "nymag.com",
#     "title": "11 Best Cat Foods 2022 | The Strategist",
#     "link": "https://nymag.com/strategist/article/best-cat-food.html",
#     "original": "https://pyxis.nymag.com/v1/imgs/54c/950/eff84c687e50d533f210c2582ffd570142-31-cat-food.2x.rsocial.w600.jpg",
#     "is_product": false
#   },
#   {
#     "position": 43,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcShX3G--rOqjQXhhag_YrDAxCTZ00mdX8CCqA&usqp=CAU",
#     "source": "hartz.com",
#     "title": "Seven Steps to Toilet Training Your Cat | Hartz",
#     "link": "https://www.hartz.com/seven-steps-to-toilet-training-your-cat/",
#     "original": "https://www.hartz.com/wp-content/uploads/2021/10/seven-steps-to-toilet-train-cat-1.jpg",
#     "is_product": false
#   },
#   {
#     "position": 44,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0368m9d6iodinCvX4m-Xa36ERR-QpYkdxAQ&usqp=CAU",
#     "source": "everydayhealth.com",
#     "title": "10 Cat Exercises Your Pet Will Enjoy | Everyday Health",
#     "link": "https://www.everydayhealth.com/pet-health/ten-cat-exercises.aspx",
#     "original": "https://images.everydayhealth.com/images/pet-health/cs-pet-health-cat-exercises-1440x810.jpg",
#     "is_product": false
#   },
#   {
#     "position": 45,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrtxQ6x4zIDxIc_dTKXEivWbe07agazd2LWA&usqp=CAU",
#     "source": "humanesociety.org",
#     "title": "Cats | The Humane Society of the United States",
#     "link": "https://www.humanesociety.org/animals/cats",
#     "original": "https://www.humanesociety.org/sites/default/files/styles/1240x698/public/2018/06/cat-217679.jpg?h=c4ed616d&itok=3qHaqQ56",
#     "is_product": false
#   },
#   {
#     "position": 46,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcfl-0x3GfXpL5l4Di49__IP8ZEgJ1NZJSsA&usqp=CAU",
#     "source": "cfa.org",
#     "title": "The Cat Fanciers' Association, Inc – World's Largest Registry of Pedigreed  Cats",
#     "link": "https://cfa.org/",
#     "original": "https://cfa.org/wp-content/uploads/2022/03/Banner4.jpg",
#     "is_product": false
#   },
#   {
#     "position": 47,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrRjojnZnU3SMwTWV1nFEgoucVkOcmomTQ8A&usqp=CAU",
#     "source": "cnn.com",
#     "title": "A cat was finally reunited with her family after spending 3 weeks lost in a  Boston airport | CNN Travel",
#     "link": "https://www.cnn.com/travel/article/boston-logan-airport-cat-rescue-trnd/index.html",
#     "original": "http://cdn.cnn.com/cnnnext/dam/assets/220715110702-boston-logan-airport-cat-rescue-trnd.jpg",
#     "is_product": true
#   },
#   {
#     "position": 48,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRenxgUl17Kbad4oplUrH6Nei3nB4wDxCFnSw&usqp=CAU",
#     "source": "vanityfair.com",
#     "title": "Hey Weirdos: Cats Is Now Available to Spice Up Your Quarantine | Vanity Fair",
#     "link": "https://www.vanityfair.com/hollywood/2020/03/cats-digital-coronavirus",
#     "original": "https://media.vanityfair.com/photos/5e27310def889c00087c7928/master/pass/taylor-swift-cats.jpg",
#     "is_product": false
#   },
#   {
#     "position": 49,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5wpGR32-QTFQ6R5R0WGe6uDSQT5qahTWVEw&usqp=CAU",
#     "source": "catadoptionteam.org",
#     "title": "Cat Adoption Team | Sherwood Cat Rescue | Cat Adoption Center",
#     "link": "https://catadoptionteam.org/",
#     "original": "https://catadoptionteam.org/wp-content/uploads/2019/05/Transparent-OrangeWhiteCat-764x1024.png",
#     "is_product": false
#   },
#   {
#     "position": 50,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0DXioVO_tzMxi76bHH_Is5mtquYoKJcx8Ag&usqp=CAU",
#     "source": "nytimes.com",
#     "title": "How the Cat Gets Its Stripes: It's Genetics, Not a Folk Tale - The New York  Times",
#     "link": "https://www.nytimes.com/2021/09/07/science/cat-stripes-genetics.html",
#     "original": "https://static01.nyt.com/images/2021/09/14/science/07CAT-STRIPES/07CAT-STRIPES-mobileMasterAt3x.jpg",
#     "is_product": false
#   },
#   {
#     "position": 51,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTCKgcxc5Ma6iJEF93H2S4vSP_sHp5RzMc3Xg&usqp=CAU",
#     "source": "youtube.com",
#     "title": "Baby Cats - Cute and Funny Cat Videos Compilation #38 | Aww Animals -  YouTube",
#     "link": "https://www.youtube.com/watch?v=Ii8h7DCIcMo",
#     "original": "https://i.ytimg.com/vi/Ii8h7DCIcMo/maxresdefault.jpg",
#     "is_product": false
#   },
#   {
#     "position": 52,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxIGkGEOxhohZ7wOw0PZM461PzcdhUFBjHSA&usqp=CAU",
#     "source": "catamazing.com",
#     "title": "Cat Amazing – Best Interactive Toys & Feeders for Cats & Kittens!",
#     "link": "https://catamazing.com/",
#     "original": "https://cdn.shopify.com/s/files/1/1832/0821/files/catshark.jpg?v=1649869148",
#     "is_product": false
#   },
#   {
#     "position": 53,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-sLgf6bCvUFxwQ_5TnXxSDeK-5dug_kP5Nw&usqp=CAU",
#     "source": "countrysideveterinaryclinic.org",
#     "title": "20 Cat Facts That'll Blow Your Kitty-Crazed Mind",
#     "link": "https://www.countrysideveterinaryclinic.org/services/cats/blog/20-cat-facts-thatll-blow-your-kitty-crazed-mind",
#     "original": "https://www.countrysideveterinaryclinic.org/sites/default/files/interesting-cat-facts.jpg",
#     "is_product": false
#   },
#   {
#     "position": 54,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHd1BoWFdA0rEat7NIQrzS6bJN9earlHaz0A&usqp=CAU",
#     "source": "treehugger.com",
#     "title": "Cat Sounds and What They Mean",
#     "link": "https://www.treehugger.com/cat-sounds-and-what-they-mean-4864314",
#     "original": "https://www.treehugger.com/thmb/6L9fqLaIt1e4p0_t1KruzzwugMg=/3552x2217/filters:fill(auto,1)/GettyImages-593450425-5176c57c7b77417f9dd01dfb43827e7b.jpg",
#     "is_product": false
#   },
#   {
#     "position": 55,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgXQBwlHdxT9O92lyr4tJaByT7eS1uadApeA&usqp=CAU",
#     "source": "theguardian.com",
#     "title": "Owners warned not to kiss pets after first cat infected with coronavirus in  UK | Coronavirus | The Guardian",
#     "link": "https://www.theguardian.com/world/2020/jul/27/pet-cat-diagnosed-with-covid-19-uk-government-confirms",
#     "original": "https://i.guim.co.uk/img/media/c9b0aad22638133aa06cd68347bed2390b555e63/0_477_2945_1767/master/2945.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=97bf92d90f51da7067d00f8156512925",
#     "is_product": false
#   },
#   {
#     "position": 56,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReLDHsAIhgLgFpupyZg0CtevFcI2NY9WkoOQ&usqp=CAU",
#     "source": "americanhumane.org",
#     "title": "Adopt-A-Cat Month® - American Humane - American Humane",
#     "link": "https://www.americanhumane.org/initiative/adopt-a-cat-month/",
#     "original": "https://www.americanhumane.org/app/uploads/2016/08/animals-cats-cute-45170-min.jpg",
#     "is_product": false
#   },
#   {
#     "position": 57,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRB2ysrPvhIBLoo22vh1IW1cPRT4YEaSA52Rg&usqp=CAU",
#     "source": "bbc.com",
#     "title": "Why do we think cats are unfriendly? - BBC Future",
#     "link": "https://www.bbc.com/future/article/20191024-why-do-we-think-cats-are-unfriendly",
#     "original": "https://ychef.files.bbci.co.uk/976x549/p07ryyyj.jpg",
#     "is_product": false
#   },
#   {
#     "position": 58,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTtQdQTj1Ws2aZNrkmNU_QENnY__UdKymEGWQ&usqp=CAU",
#     "source": "npr.org",
#     "title": "Escaped pet cat Rowdy is finally caught at Boston airport : NPR",
#     "link": "https://www.npr.org/2022/07/13/1111333510/cat-boston-logan-airport",
#     "original": "https://media.npr.org/assets/img/2022/07/13/ap22194581263412_custom-d6464f6438abdb0983fb8c47a51fe2c7dc146de1-s1100-c50.jpg",
#     "is_product": false
#   },
#   {
#     "position": 59,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUxzwTf407A4Rd_kFyxkZnTvQj5YUjxKMO_g&usqp=CAU",
#     "source": "nature.com",
#     "title": "First reported case of a person getting COVID from a cat",
#     "link": "https://www.nature.com/articles/d41586-022-01792-y",
#     "original": "https://images.nature.com/original/magazine-assets/d41586-022-01792-y/d41586-022-01792-y_23218332.jpg",
#     "is_product": false
#   },
#   {
#     "position": 60,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTkSjqULTzrywh3G-nZ92XHwtyI4-P8y8AkSA&usqp=CAU",
#     "source": "livescience.com",
#     "title": "How do cats get their stripes? | Live Science",
#     "link": "https://www.livescience.com/cat-genes-for-stripes-spots.html",
#     "original": "https://cdn.mos.cms.futurecdn.net/KYEJp9vem3QQFGhi25SYx4-1200-80.jpg",
#     "is_product": false
#   },
#   {
#     "position": 61,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZd1_afw2DFIYmvD0qqr3B_wQZSFDTKvZVCw&usqp=CAU",
#     "source": "cdc.gov",
#     "title": "Cats | Bringing an Animal into U.S. | Importation | CDC",
#     "link": "https://www.cdc.gov/importation/bringing-an-animal-into-the-united-states/cats.html",
#     "original": "https://www.cdc.gov/importation/images/cat.jpg",
#     "is_product": false
#   },
#   {
#     "position": 62,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTe4BJINBwG-mGlIZu4FpdrdT7eTEO36cPuRA&usqp=CAU",
#     "source": "cnn.com",
#     "title": "Cat supplies you need, according to vets | CNN Underscored",
#     "link": "https://www.cnn.com/cnn-underscored/pets/cat-supplies",
#     "original": "https://cdn.cnn.com/cnnnext/dam/assets/210303111816-catsupplieslead.jpg",
#     "is_product": false
#   },
#   {
#     "position": 63,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThTFHNvudF14DrJhIbjvNi8KhuKPaOrCivYw&usqp=CAU",
#     "source": "pexels.com",
#     "title": "10,000+ Best Cat Photos · 100% Free Download · Pexels Stock Photos",
#     "link": "https://www.pexels.com/search/cat/",
#     "original": "https://images.pexels.com/photos/69932/tabby-cat-close-up-portrait-69932.jpeg?cs=srgb&dl=pexels-pixabay-69932.jpg&fm=jpg",
#     "is_product": false
#   },
#   {
#     "position": 64,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJLvpg1mkThe9cUMYqnya_7p6FTU9AuqaMkA&usqp=CAU",
#     "source": "sci-news.com",
#     "title": "Cats Learn Names of Their Feline Friends, New Study Shows | Sci-News.com",
#     "link": "http://www.sci-news.com/biology/cat-friend-names-10897.html",
#     "original": "http://cdn.sci-news.com/images/enlarge9/image_10897e-Cats.jpg",
#     "is_product": false
#   },
#   {
#     "position": 65,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ_naKHZkvdE9ChlyR5oZWAroKqRAJ_vV02Aw&usqp=CAU",
#     "source": "unsplash.com",
#     "title": "Sitting Cat Pictures | Download Free Images on Unsplash",
#     "link": "https://unsplash.com/s/photos/sitting-cat",
#     "original": "https://images.unsplash.com/photo-1609779361684-8196b3a0abf1?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8MXx8c2l0dGluZyUyMGNhdHxlbnwwfHwwfHw%3D&w=1000&q=80",
#     "is_product": false
#   },
#   {
#     "position": 66,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6fH4WcqPLntpPILC1Ag-_D7dkrljytz9iNg&usqp=CAU",
#     "source": "mcgill.ca",
#     "title": "Should I Attach a Bell to My Cat's Collar? | Office for Science and Society  - McGill University",
#     "link": "https://www.mcgill.ca/oss/article/general-science/should-i-attach-bell-my-cats-collar",
#     "original": "https://www.mcgill.ca/oss/files/oss/styles/hd/public/cute-3281819_1920.jpg?itok=1tLaIhp2&timestamp=1569533232",
#     "is_product": false
#   },
#   {
#     "position": 67,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCC4squwzXz2nJjoLg54HZI__bsl39JUc6NQ&usqp=CAU",
#     "source": "washingtonpost.com",
#     "title": "Cats do have facial expressions, but you probably can't read them - The  Washington Post",
#     "link": "https://www.washingtonpost.com/science/2019/11/30/cats-do-have-facial-expressions-you-probably-cant-read-them/",
#     "original": "https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/WALN4MAIT4I6VLRIPUMJQAJIME.jpg",
#     "is_product": false
#   },
#   {
#     "position": 68,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR48ivSfj5ffrq25JXBzNVE-3kbvHxEVKeDUw&usqp=CAU",
#     "source": "med.stanford.edu",
#     "title": "Spots, stripes and blotches: Color patterns of cat fur tracked to a key  gene | News Center | Stanford Medicine",
#     "link": "https://med.stanford.edu/news/all-news/2021/09/cat-fur-color-patterns.html",
#     "original": "http://med.stanford.edu/content/dam/sm-news/images/2021/09/cat_by-Kateryna-T-Unsplash.jpg",
#     "is_product": false
#   },
#   {
#     "position": 69,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR59gy93VgTjlAb8R2ruLYD607S_Sr9fNjdVw&usqp=CAU",
#     "source": "newyorker.com",
#     "title": "Cats,” Reviewed: It's Not Quite Weird Enough | The New Yorker",
#     "link": "https://www.newyorker.com/culture/culture-desk/cats-reviewed-its-not-quite-weird-enough",
#     "original": "https://media.newyorker.com/photos/5dfab39dde5fcf00086aec77/16:9/w_2559,h_1439,c_limit/Lane-Cats.jpg",
#     "is_product": false
#   },
#   {
#     "position": 70,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrOPVQcvpz2AjKdURKJ0-FLJp0ctJrI3n9Dw&usqp=CAU",
#     "source": "battersea.org.uk",
#     "title": "Is my cat happy? | Battersea Dogs & Cats Home",
#     "link": "https://www.battersea.org.uk/pet-advice/cat-advice/my-cat-happy",
#     "original": "https://d1wn0q81ehzw6k.cloudfront.net/additional/thul/media/6dfd714b342b11fd?w=890&h=590&crop=1",
#     "is_product": false
#   },
#   {
#     "position": 71,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRPE15tyTSLTgZBucvcVzJPiNFZhe27mKyiwA&usqp=CAU",
#     "source": "beverlyhillsvets.com",
#     "title": "A Look at Cat Behavior (and Some Things Cats Wish Owners Would Stop Doing)  | Beverly Hills Veterinary Associates | Beverly Hills Veterinary  Associates, Beverly Hills, MI",
#     "link": "https://www.beverlyhillsvets.com/blog/a-look-at-cat-behavior-and-some-things-cats-wish-owners-would-stop-doing/",
#     "original": "https://www.beverlyhillsvets.com/blog/wp-content/uploads/2019/10/iStock-1092587292-1.jpg",
#     "is_product": false
#   },
#   {
#     "position": 72,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ62ur0odxYMkCMVPnIOJScno4brOZPB_gOBA&usqp=CAU",
#     "source": "theatlantic.com",
#     "title": "How Cats Used Humans to Conquer the World - The Atlantic",
#     "link": "https://www.theatlantic.com/science/archive/2017/06/cat-domination/530685/",
#     "original": "https://cdn.theatlantic.com/thumbor/OgQgHFiqAd92pArI1zjmcUHjoSc=/144x0:2411x1700/1200x900/media/img/mt/2017/06/shutterstock_319985324/original.jpg",
#     "is_product": false
#   },
#   {
#     "position": 73,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQp2pAfF3jUGXHmUvDr_r48QfS9U1ZKJR_IPw&usqp=CAU",
#     "source": "letstalkscience.ca",
#     "title": "The Science Behind the Calico Cat's Colours | Let's Talk Science",
#     "link": "https://letstalkscience.ca/educational-resources/stem-in-context/science-behind-calico-cats-colours",
#     "original": "https://letstalkscience.ca/sites/default/files/2020-03/calico-cat.jpg",
#     "is_product": false
#   },
#   {
#     "position": 74,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTiJGHMudbLWYTlQ9dcRyPAYKRRlUaOxh1J3Q&usqp=CAU",
#     "source": "petfinder.com",
#     "title": "Cats: Adoption, Bringing A Cat Home and Care",
#     "link": "https://www.petfinder.com/cats/",
#     "original": "https://d17fnq9dkz9hgj.cloudfront.net/uploads/2013/09/cat-black-superstitious-fcs-cat-myths-162286659.jpg",
#     "is_product": false
#   },
#   {
#     "position": 75,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSyVzsy1Vk-vy6SUfQ-MreN7oAc9bJWYaB5mg&usqp=CAU",
#     "source": "vox.com",
#     "title": "Cats review: A deep and inscrutable movie - Vox",
#     "link": "https://www.vox.com/culture/2019/12/18/21021186/cats-review",
#     "original": "https://cdn.vox-cdn.com/thumbor/MfAL89LfeltyZgd9Ra8C2iBjq3U=/1400x1400/filters:format(jpeg)/cdn.vox-cdn.com/uploads/chorus_asset/file/19539772/cats4.jpg",
#     "is_product": false
#   },
#   {
#     "position": 76,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTK3uu45UWvHLN6-4kjP9lfUIv0MzXiEEgNeQ&usqp=CAU",
#     "source": "aspcapetinsurance.com",
#     "title": "How Much Does It Cost to Have a Cat? | ASPCA Pet Insurance",
#     "link": "https://www.aspcapetinsurance.com/resources/cat-ownership-cost/",
#     "original": "https://d3544la1u8djza.cloudfront.net/APHI/Blog/2020/07-23/How+Much+Does+It+Cost+to+Have+a+Cat+_+ASPCA+Pet+Insurance+_+black+cat+with+yellow+eyes+peeking+out-min.jpg",
#     "is_product": false
#   },
#   {
#     "position": 77,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTGHr04Fs8PJg3G1RBOirggin0EfJQCn46D2w&usqp=CAU",
#     "source": "dailypaws.com",
#     "title": "How to Tell When a Cat is Ready to Give Birth | Daily Paws",
#     "link": "https://www.dailypaws.com/cats-kittens/health-care/cat-neutering-spaying/how-to-tell-when-a-cat-is-ready-to-give-birth",
#     "original": "https://imagesvc.meredithcorp.io/v3/mm/image?url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F47%2F2022%2F05%2F05%2Fhow-to-tell-when-a-cat-is-ready-to-give-birth-1394646981-2000.jpg&q=60",
#     "is_product": false
#   },
#   {
#     "position": 78,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgJ9T7hOwIBDK63T7aTXhIQ--yKKHsXtfkKg&usqp=CAU",
#     "source": "thespruce.com",
#     "title": "Ways to Keep Cats Out of Your Yard or Garden",
#     "link": "https://www.thespruce.com/cat-repellents-to-keep-cats-out-of-your-yard-2132573",
#     "original": "https://www.thespruce.com/thmb/N7rkkIx1G4KJSG_CtqUFPATQr4w=/4628x3471/smart/filters:no_upscale()/cat-repellents-to-keep-cats-out-of-your-yard-2132573-hero-23591eb06a8f4c909238657db9fbfb4e.jpg",
#     "is_product": false
#   },
#   {
#     "position": 79,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrlu75rwhLM3Ms3K8iI1c2FqgSyE3Eutvkcw&usqp=CAU",
#     "source": "primalpetfoods.com",
#     "title": "Stages of a Cat's Life – Primal Pet Foods",
#     "link": "https://primalpetfoods.com/blogs/news/stages-of-a-cat-s-life",
#     "original": "https://cdn.shopify.com/s/files/1/1788/4235/files/PPF-BlogUpdate-Thumbs_0041_42_Cat-Stages.jpg",
#     "is_product": false
#   },
#   {
#     "position": 80,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgOQoiWOiwj6_21uZD_q6KTrh2HaqTWYwN5Q&usqp=CAU",
#     "source": "greensboro.carolinavet.com",
#     "title": "Why are my cat's eyes watering? | Greensboro Vet | Carolina Veterinary  Specialists",
#     "link": "https://www.greensboro.carolinavet.com/site/greensboro-specialty-veterinary-blog/2020/08/26/cat-eye-watering",
#     "original": "https://d2zp5xs5cp8zlg.cloudfront.net/image-30938-800.jpg",
#     "is_product": false
#   },
#   {
#     "position": 81,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRYa_5zMN5cUvHF70-aI_rzGzhcIMQ53Ssu1w&usqp=CAU",
#     "source": "timesofindia.indiatimes.com",
#     "title": "Cats are lucky charms! - Times of India",
#     "link": "https://timesofindia.indiatimes.com/life-style/relationships/pets/cats-are-lucky-charms/articleshow/72295856.cms",
#     "original": "https://m.timesofindia.com/thumb/msid-72295960,width-1070,height-580,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/72295960.jpg",
#     "is_product": false
#   },
#   {
#     "position": 82,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTv4eHKh1qN906A0HB9qTmKHh7jAHs8JHit5w&usqp=CAU",
#     "source": "hindustantimes.com",
#     "title": "International Cat Day: 20 interesting cat facts you must know - Hindustan  Times",
#     "link": "https://www.hindustantimes.com/more-lifestyle/international-cat-day-20-interesting-cat-facts-you-must-know/story-iv9FrRfnckBynrzIbgmlGO.html",
#     "original": "https://images.hindustantimes.com/rf/image_size_630x354/HT/p2/2019/08/08/Pictures/_6bda0940-b9ad-11e9-98cb-e738ad509720.jpg",
#     "is_product": false
#   },
#   {
#     "position": 83,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3qtjuw1MSDZBcDZXxpvoyOoZbCNjY3UeXIA&usqp=CAU",
#     "source": "aspca.org",
#     "title": "Common Cat Behavior Issues | ASPCA",
#     "link": "https://www.aspca.org/pet-care/cat-care/common-cat-behavior-issues",
#     "original": "https://www.aspca.org/sites/default/files/common-cat-behavior-issues_facebook.jpg",
#     "is_product": false
#   },
#   {
#     "position": 84,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRhzbC_j6VtgNx1JKAGWftcTJDo8iYLzXZhEQ&usqp=CAU",
#     "source": "pexels.com",
#     "title": "10,000+ Best Cat Photos · 100% Free Download · Pexels Stock Photos",
#     "link": "https://www.pexels.com/search/cat/",
#     "original": "https://images.pexels.com/photos/1170986/pexels-photo-1170986.jpeg?cs=srgb&dl=pexels-evg-kowalievska-1170986.jpg&fm=jpg",
#     "is_product": false
#   },
#   {
#     "position": 85,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQIsPpqzQ-tBEVdo4-g5FdjutF8w3t0h9TTvA&usqp=CAU",
#     "source": "brusselstimes.com",
#     "title": "Coronavirus: Belgian cat infected by owner",
#     "link": "https://www.brusselstimes.com/103003/coronavirus-belgian-woman-infected-her-cat",
#     "original": "https://storage.googleapis.com/article-contents/media/2020/03/cat-4429808_960_720.jpg",
#     "is_product": false
#   },
#   {
#     "position": 86,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZSlpNFS2lmIjC-WxJ5u84WvOaH-oH_DaaOw&usqp=CAU",
#     "source": "newscientist.com",
#     "title": "Gene responsible for cat fur patterns could lead to designer pets | New  Scientist",
#     "link": "https://www.newscientist.com/article/2289384-gene-responsible-for-cat-fur-patterns-could-lead-to-designer-pets/",
#     "original": "https://images.newscientist.com/wp-content/uploads/2021/09/07151312/PRI_198391221.jpg",
#     "is_product": false
#   },
#   {
#     "position": 87,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKmjfwGrqEhng5-9gsozZ0Inv0NN_ckrozkw&usqp=CAU",
#     "source": "play.google.com",
#     "title": "Kitty Cat Resort - Apps on Google Play",
#     "link": "https://play.google.com/store/apps/details?id=com.fathermade.catisland&hl=en_US&gl=US",
#     "original": "https://play-lh.googleusercontent.com/ShfPMkvWHGnOGuap1gyl06Mo4gge1DZOug_rgQlqEcgvJw7NQkATB3CHJ3mQI8QXc1g",
#     "is_product": false
#   },
#   {
#     "position": 88,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRv7t4GtTX9MDwzbf67MQFaM6fxiQUZ4FImvg&usqp=CAU",
#     "source": "independent.co.uk",
#     "title": "Cat returns home after family believe they cremated him | The Independent",
#     "link": "https://www.independent.co.uk/news/uk/home-news/cat-returns-home-cremation-cheshire-b1866833.html",
#     "original": "https://static.independent.co.uk/2021/06/16/08/newFile-4.jpg?quality=75&width=982&height=726&auto=webp",
#     "is_product": false
#   },
#   {
#     "position": 89,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT9-YouEbFysqdVKhae8zApG6O8P1JYoAAHtQ&usqp=CAU",
#     "source": "fearfreehappyhomes.com",
#     "title": "What Movement and Gait Tell You About Your Cat | Fear Free Happy Homes",
#     "link": "https://www.fearfreehappyhomes.com/what-movement-and-gait-tell-you-about-your-cat/",
#     "original": "https://www.fearfreehappyhomes.com/wp-content/uploads/2020/08/shutterstock_707431309-e1554172878508.jpg",
#     "is_product": false
#   },
#   {
#     "position": 90,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmMdhnrmgU-whtb9kJc56WQhWAZ0j7CHrwZg&usqp=CAU",
#     "source": "news18.com",
#     "title": "International Cat Day 2021: 5 Signs That Show You are a Cat Person",
#     "link": "https://www.news18.com/news/lifestyle/international-cat-day-2021-5-signs-that-show-you-are-a-cat-person-4059512.html",
#     "original": "https://images.news18.com/ibnlive/uploads/2021/08/1628396465_cat-people-1600x1200.jpg",
#     "is_product": false
#   },
#   {
#     "position": 91,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ3JD4BJHh9xr_ME4r7qy-v2rR-vG8c2jiyww&usqp=CAU",
#     "source": "vcahospitals.com",
#     "title": "Creating a Weight Reduction Plan for Cats | VCA Animal Hospital",
#     "link": "https://vcahospitals.com/know-your-pet/creating-a-weight-reduction-plan-for-cats",
#     "original": "https://vcahospitals.com/-/media/2/vca/images/lifelearn-images-foldered/391/slimcat_side_view_orange_2018-01scaler.ashx",
#     "is_product": false
#   },
#   {
#     "position": 92,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbQ91cdbKfkUGqMotW7X2Vli6ImtZXIBEpiQ&usqp=CAU",
#     "source": "mercurynews.com",
#     "title": "Photos: Who's the prettiest cat in the Cat Fanciers Association competition?",
#     "link": "https://www.mercurynews.com/2022/04/03/photos-whos-the-prettiest-cat-me-ow",
#     "original": "https://www.mercurynews.com/wp-content/uploads/2022/04/EBT-L-CATSHOW-0403-11.jpg?w=525",
#     "is_product": false
#   },
#   {
#     "position": 93,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-NhF121PxTDLNEBnqnIFFUGWxdshtfJE8Pg&usqp=CAU",
#     "source": "cbc.ca",
#     "title": "Do you speak cat? Common feline postures decoded | CBC Life",
#     "link": "https://www.cbc.ca/life/pets/do-you-speak-cat-common-feline-postures-decoded-1.5256356",
#     "original": "https://i.cbc.ca/1.5256404.1566499707!/fileImage/httpImage/image.jpg_gen/derivatives/16x9_940/cat-behaviour.jpg",
#     "is_product": false
#   },
#   {
#     "position": 94,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRvhIyQ1DClkUsnkyZu30GKYr3HZqDPFGulw&usqp=CAU",
#     "source": "goodrx.com",
#     "title": "What Are Cat Seizures? The Telltale Signs, Causes, & Recovery - GoodRx",
#     "link": "https://www.goodrx.com/pet-health/cat/understanding-cat-seizures",
#     "original": "https://images.ctfassets.net/4f3rgqwzdznj/4IMpm0CX5kGpinJiG2ME8r/2dae4b7ac7c3008359bc7fe690bab18f/cat_on_fence_outside-1324776163.jpg",
#     "is_product": false
#   },
#   {
#     "position": 95,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRlG0eFSf1QnHCO6OYbkkTMC1LO9xl7cQyzPA&usqp=CAU",
#     "source": "nhm.ac.uk",
#     "title": "Fantastic felines: a world of wild cats | Natural History Museum",
#     "link": "https://www.nhm.ac.uk/discover/a-world-of-wild-cats.html",
#     "original": "https://www.nhm.ac.uk/content/dam/nhmwww/discover/wild-cats/pallas-cat-face-close-up-full-width.jpg",
#     "is_product": false
#   },
#   {
#     "position": 96,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRt9IrRQDV2PVJo6cC04GvhnbqxUlLKuGJLxg&usqp=CAU",
#     "source": "insider.com",
#     "title": "Why Do Cats Knead? 6 Reasons for This Adorable Behavior",
#     "link": "https://www.insider.com/guides/pets/why-do-cats-knead",
#     "original": "https://i.insider.com/61fc1b1bb0ec040018d0b7e9?width=750&format=jpeg&auto=webp",
#     "is_product": false
#   },
#   {
#     "position": 97,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-rZEBfvH_ItZFzyrNSCK_H3zGZKrhtcggIQ&usqp=CAU",
#     "source": "amazon.com",
#     "title": "Cat Sounds:Amazon.com:Appstore for Android",
#     "link": "https://www.amazon.com/Ape-Apps-Cat-Sounds/dp/B08FXPJVC6",
#     "original": "https://images-na.ssl-images-amazon.com/images/I/71+mDoHG4mL.png",
#     "is_product": false
#   },
#   {
#     "position": 98,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLdls-mU0gKRuIC3S3tVwerRTtUHPLD7JxdA&usqp=CAU",
#     "source": "ndtv.com",
#     "title": "International Cat Day 2021: Date, Theme And Significance",
#     "link": "https://www.ndtv.com/offbeat/international-cat-day-2021-date-theme-and-significance-2505460",
#     "original": "https://c.ndtvimg.com/2020-08/h5mk7js_cat-generic_625x300_28_August_20.jpg?im=Resize=(1230,900)",
#     "is_product": false
#   },
#   {
#     "position": 99,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZQIDnydkpuJvQtwUwbC4_rLtFjLxUKAKo9A&usqp=CAU",
#     "source": "smithsonianmag.com",
#     "title": "Human Genomes Are Surprisingly Cat-Like | Smart News| Smithsonian Magazine",
#     "link": "https://www.smithsonianmag.com/smart-news/human-genomes-are-surprisingly-cat-like-180978332/",
#     "original": "https://th-thumbnailer.cdn-si-edu.com/wVkY4ktA-0JvRsuh8EASm6NoSNs=/1000x750/filters:no_upscale():focal(978x630:979x631)/https://tf-cmsv2-smithsonianmag-media.s3.amazonaws.com/filer/db/82/db8234fc-f167-4285-82bd-123d035e32ad/cats.jpg",
#     "is_product": false
#   },
#   {
#     "position": 100,
#     "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4it_Jqeo2FMOA-0f2yJk5uYJ3YTa1j7MVSA&usqp=CAU",
#     "source": "livescience.com",
#     "title": "Cat infected with COVID-19 from owner in Belgium | Live Science",
#     "link": "https://www.livescience.com/cat-infected-covid-19-from-owner.html",
#     "original": "https://cdn.mos.cms.futurecdn.net/VSy6kJDNq2pSXsCzb6cvYF.jpg",
#     "is_product": false
#   }
# ]
# Downloading 0 image...
# Downloading 1 image...
# Downloading 2 image...
# Downloading 3 image...
# Downloading 4 image...
# Downloading 5 image...
# Downloading 6 image...
# Downloading 7 image...
# Downloading 8 image...
# Downloading 9 image...
# Downloading 10 image...
# Downloading 11 image...
# Downloading 12 image...
# Downloading 13 image...
# Downloading 14 image...
# Downloading 15 image...
# Downloading 16 image...
# Downloading 17 image...
# Downloading 18 image...
# Downloading 19 image...
# Downloading 20 image...
# Downloading 21 image...
# Downloading 22 image...
# Downloading 23 image...
# Downloading 24 image...
# Downloading 25 image...
# Downloading 26 image...
# Downloading 27 image...
# Downloading 28 image...
# Downloading 29 image...
# Downloading 30 image...
# Downloading 31 image...
# Downloading 32 image...
# Downloading 33 image...
# Downloading 34 image...
# Downloading 35 image...
# Downloading 36 image...
# Downloading 37 image...
# Downloading 38 image...
# Downloading 39 image...
# Downloading 40 image...
# Downloading 41 image...
# Downloading 42 image...
# Downloading 43 image...
# Downloading 44 image...
# Downloading 45 image...
# Downloading 46 image...
# Downloading 47 image...
# Downloading 48 image...
# Downloading 49 image...
# Downloading 50 image...
# Downloading 51 image...
# Downloading 52 image...
# Downloading 53 image...
# Downloading 54 image...
# Downloading 55 image...
# Downloading 56 image...
# Downloading 57 image...
# Downloading 58 image...
# Downloading 59 image...
# Downloading 60 image...
# Downloading 61 image...
# Downloading 62 image...
# Downloading 63 image...
# Downloading 64 image...
# Downloading 65 image...
# Downloading 66 image...
# Downloading 67 image...
# Downloading 68 image...
# Downloading 69 image...
# Downloading 70 image...
# Downloading 71 image...
# Downloading 72 image...
# Downloading 73 image...
# Downloading 74 image...
# Downloading 75 image...
# Downloading 76 image...
# Downloading 77 image...
# Downloading 78 image...
# Downloading 79 image...
# Downloading 80 image...
# Downloading 81 image...
# Downloading 82 image...
# Downloading 83 image...
# Downloading 84 image...
# Downloading 85 image...
# Downloading 86 image...
# Downloading 87 image...
# Downloading 88 image...
# Downloading 89 image...
# Downloading 90 image...
# Downloading 91 image...
# Downloading 92 image...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 47>()
#      44             print(e)
#      45             print(f"Error downloading {index} image. Error =", e)
# ---> 47 get_google_images()
#
# Input In [12], in get_google_images()
#      36 # filepath is current working directory + SerpApi_Images + params["q"] + index + .jpg
#      37 filepath = os.path.join("./SerpApi_Images/", params["q"] + str(index) + ".jpg")
# ---> 39 response = requests.get(image['original'], headers=headers).content
#      40 with open(filepath, "wb") as f:
#      41     f.write(response)
#
# File ~/miniconda3/envs/cv_env/lib/python3.8/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/miniconda3/envs/cv_env/lib/python3.8/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/cv_env/lib/python3.8/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/miniconda3/envs/cv_env/lib/python3.8/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/cv_env/lib/python3.8/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 # Trigger any extra validation we need to do.
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     385     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:1010, in HTTPSConnectionPool._validate_conn(self, conn)
#    1008 # Force connect early to allow us to validate the connection.
#    1009 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010     conn.connect()
#    1012 if not conn.is_verified:
#    1013     warnings.warn(
#    1014         (
#    1015             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1020         InsecureRequestWarning,
#    1021     )
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     402 if (
#     403     not self.ca_certs
#     404     and not self.ca_cert_dir
#    (...)
#     407     and hasattr(context, "load_default_certs")
#     408 ):
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#     427 if (
#     428     default_ssl_context
#     429     and self.ssl_version is None
#     430     and hasattr(self.sock, "version")
#     431     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     432 ):
#
# File ~/.local/lib/python3.8/site-packages/urllib3/util/ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:

# %%
# upload
# !pip install roboflow
from roboflow import Roboflow


# creating the Roboflow object
# obtaining your API key: https://docs.roboflow.com/rest-api#obtaining-your-api-key
rf = Roboflow(api_key="YOUR_API_KEY")

# using the workspace method on the Roboflow object
workspace = rf.workspace()
# print(workspace)
# identifying the project for upload
project = workspace.project("car-crashes")

# # uploading the image to your project
# use import os 

project.upload("<file_name>")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
